# %%
import tensorflow as tf
from model import Color_CIFAR

# %%
params = {
    'lr' : 0.0001,
    'threshold': 0.02,
    'kernel_size': 2,
    'training': True, 
    'num_epochs': 3,
    'batch_size': 64}

with tf.Session() as sess:
    c = Color_CIFAR('cifar-10-batches-py', sess, params)
    c.build_graph()
    sess.run(tf.global_variables_initializer())
    c.train()
# Out:
# Starting Epoch Number 0
# Step: 0 Accuracy: 0.005264, GenLoss: 0.028015, DisLoss: 6.259408
# Step: 5 Accuracy: 0.003906, GenLoss: 0.387930, DisLoss: 2.038815
# Step: 10 Accuracy: 0.004105, GenLoss: 0.262757, DisLoss: 2.071445
# Step: 15 Accuracy: 0.003830, GenLoss: 0.246196, DisLoss: 2.025500
# Step: 20 Accuracy: 0.004257, GenLoss: 0.351242, DisLoss: 1.702686
# Step: 25 Accuracy: 0.003006, GenLoss: 0.260413, DisLoss: 1.903789
# Step: 30 Accuracy: 0.002594, GenLoss: 0.337525, DisLoss: 1.730084
# Step: 35 Accuracy: 0.003143, GenLoss: 0.296620, DisLoss: 1.776919
# Step: 40 Accuracy: 0.003342, GenLoss: 0.270058, DisLoss: 1.846121
# Step: 45 Accuracy: 0.002975, GenLoss: 0.349526, DisLoss: 1.659868
# Step: 50 Accuracy: 0.003540, GenLoss: 0.314667, DisLoss: 1.741861
# Step: 55 Accuracy: 0.002884, GenLoss: 0.273857, DisLoss: 1.824682
# Step: 60 Accuracy: 0.004486, GenLoss: 0.300036, DisLoss: 1.752091
# Step: 65 Accuracy: 0.004181, GenLoss: 0.321812, DisLoss: 1.729387
# Step: 70 Accuracy: 0.003204, GenLoss: 0.345550, DisLoss: 1.665694
# Step: 75 Accuracy: 0.003174, GenLoss: 0.349521, DisLoss: 1.651648
# Step: 80 Accuracy: 0.003632, GenLoss: 0.311146, DisLoss: 1.750638
# Step: 85 Accuracy: 0.003769, GenLoss: 0.284301, DisLoss: 1.807070
# Step: 90 Accuracy: 0.002945, GenLoss: 0.289854, DisLoss: 1.786032
# Step: 95 Accuracy: 0.002975, GenLoss: 0.305245, DisLoss: 1.742659
# Step: 100 Accuracy: 0.003052, GenLoss: 0.332751, DisLoss: 1.683145
