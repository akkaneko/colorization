# %%
import tensorflow as tf
from model import Color_CIFAR

# %%
params = {
    'lr' : 3e-4,
    'threshold': 0.02,
    'kernel_size': 4,
    'training': True, 
    'num_epochs': 3,
    'batch_size': 128}

with tf.Session() as sess:
    c = Color_CIFAR('cifar-10-batches-py', sess, params)
    with tf.device('/gpu:0'):
        c.build_graph()
        sess.run(tf.global_variables_initializer())
        c.train()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-2-3a545ef472e8> in <module>()
#      11     with tf.device('/gpu:0'):
#      12         c.build_graph()
# ---> 13         sess.run(tf.global_variables_initializer())
#      14         c.train()
#
# /home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# /home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1289         except KeyError:
#    1290           pass
# -> 1291       raise type(e)(node_def, op, message)
#    1292
#    1293   def _extend_graph(self):
#
# InvalidArgumentError: Cannot assign a device for operation 'rgb_to_grayscale/Identity': Operation was explicitly assigned to /device:GPU:0 but available devices are [ /job:localhost/replica:0/task:0/device:CPU:0 ]. Make sure the device specification refers to a valid device.
# 	 [[Node: rgb_to_grayscale/Identity = Identity[T=DT_FLOAT, _device="/device:GPU:0"](Placeholder)]]
#
# Caused by op u'rgb_to_grayscale/Identity', defined at:
#   File "/home/akkaneko/anaconda2/lib/python2.7/runpy.py", line 174, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home/akkaneko/anaconda2/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 1008, in start
#     self._run_callback(self._callbacks.popleft())
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tornado/ioloop.py", line 759, in _run_callback
#     ret = callback()
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 536, in <lambda>
#     self.io_loop.add_callback(lambda : self._handle_events(self.socket, 0))
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2714, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2818, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2878, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-3a545ef472e8>", line 12, in <module>
#     c.build_graph()
#   File "model.py", line 25, in build_graph
#     self.bw_images = tf.image.rgb_to_grayscale(self.raw_images)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/image_ops_impl.py", line 1498, in rgb_to_grayscale
#     flt_image = convert_image_dtype(images, dtypes.float32)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/image_ops_impl.py", line 1430, in convert_image_dtype
#     return array_ops.identity(image, name=name)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/array_ops.py", line 80, in identity
#     return gen_array_ops.identity(input, name=name)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/ops/gen_array_ops.py", line 3264, in identity
#     "Identity", input=input, name=name)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/util/deprecation.py", line 454, in new_func
#     return func(*args, **kwargs)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 3155, in create_op
#     op_def=op_def)
#   File "/home/akkaneko/anaconda2/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1717, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# InvalidArgumentError (see above for traceback): Cannot assign a device for operation 'rgb_to_grayscale/Identity': Operation was explicitly assigned to /device:GPU:0 but available devices are [ /job:localhost/replica:0/task:0/device:CPU:0 ]. Make sure the device specification refers to a valid device.
# 	 [[Node: rgb_to_grayscale/Identity = Identity[T=DT_FLOAT, _device="/device:GPU:0"](Placeholder)]]
